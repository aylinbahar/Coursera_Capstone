# %% [markdown]
# ## Introduction
# *In this project the idea is finding the best place to open a new restaurant in Melbourne. This is a part of the marketting research. The concept of the restaurant that we are planning to open is health. Menu will be composed of healthy foods like soup, salads, veggies and grilled meat. The target group will be the people, who are taking care of their health. Therefore, we will focus on the neighborhoods which has the most sports complex. This is where in this project a data analysis needed. This restaurant will be runned by 3 partners and according to the result of the data analysis, their investments may change. Thus, the auidience of this data science problem are the partners of the restaurant.*

# %% [markdown]
# ## Data
# *For the comparision the neigbourhood I needed the dataset which includes names and locations of neigbourhoods. In this way I could use the cordinates to get venues from Foursquare. After a long search on internet I found the dataset from this [link](https://www.corra.com.au/australian-postcode-location-data/)
# The dataset contains all australian post codes, suburbs, and cordinate informations. With using the dataset I could extract the suburbs in state of Victoria and after that I could have the Melbourne neigbourhoods.In order to getting near by venues and their clasification the cordinates for all neigbhbours was needed.*

# %% [markdown]
# ## Methodology
#
# To reach our goal we had ask some questions such as:
# What is the promblem?
# Which data we needed?
# Which model we should use to have the answer?
#
# *In this project problem is not knowing the best neighbourhood to open a restaurant which sells healthy foods in Melbourne. Instead of choosing the location randomly the partners of the restaurant made a market research. As a part of this research they needed to know the locations where more people prefer to go gym, fitness center or yoga studio. This leads them to data scientist to figure ou which neighbourhood our target auidience is living in.After suburb list and their coordinates and the venue information have acquired, k-means clustering used to finding best location.*

# %% [markdown]
# ## Results
#
# After sorting all neigbourhood ordering by the frequency of gyms they have, the data clustered and the results below obtained.
#
# ![Capture.PNG](attachment:Capture.PNG)
#
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ## Conclusion
#
# *By using the map above we can say that the best location to open a healthy food restaurant is Port Melbourne and Southbank and center.The results mat be evaluated by finding detailed information like population, transportation etc. For now I just found a general result which is based on sport complexes and their locations.*
